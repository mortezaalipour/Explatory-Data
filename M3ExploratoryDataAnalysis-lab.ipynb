# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify the distribution of data in the dataset.
#
# *   Identify outliers in the dataset.
#
# *   Remove outliers from the dataset.
#
# *   Identify correlation between features in the dataset.

# %% [markdown]
# ***

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
df["ConvertedComp"].plot(kind="kde")
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
df["ConvertedComp"].plot(kind="hist", edgecolor="black")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
df["ConvertedComp"].median()
# Out:
# 57745.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df["Gender"].value_counts()
# Out:
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df_woman=df[df['Gender']=='Woman']
print("Woman Median:", df_woman['ConvertedComp'].median())
# Out:
# Woman Median: 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df["Age"].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here

df["Age"].plot(kind="hist", edgecolor="black")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
sns.boxplot(x=df["ConvertedComp"])


df["ConvertedComp"].mean()
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x=df["Age"])
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
Q1 = df['ConvertedComp'].quantile(0.25)
Q3 = df['ConvertedComp'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
df["ConvertedComp"].min()
max= df["ConvertedComp"].max()

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
def find_outliers_IQR(df):

   q1=df.quantile(0.25)

   q3=df.quantile(0.75)

   IQR=q3-q1

   outliers = df[((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]

   return outliers
   
find_outliers_IQR(df["ConvertedComp"])
# Out:
# 3         455352.0
# 13       1100000.0
# 45        229016.0
# 46       2000000.0
# 60       1000000.0
#            ...
# 11296     840000.0
# 11303    1000000.0
# 11350     300000.0
# 11353     260000.0
# 11369     701196.0
# Name: ConvertedComp, Length: 879, dtype: float64

# %%
from statistics import median


((df['ConvertedComp'] < (Q1 - 1.5 * IQR)) | (df['ConvertedComp'] > (Q3 + 1.5 * IQR))).sum()
df["ConvertedComp"].median()
# Out:
# 57745.0

# %%
mask = (df['ConvertedComp'] < (Q1 - 1.5 * IQR)) | (df['ConvertedComp'] > (Q3 + 1.5 * IQR))
df[mask] = np.nan
df['ConvertedComp'].mean()
# Out:
# 59883.20838915799

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
print(df.shape)
print(df['ConvertedComp'].gt(Q3 + 1.5*IQR).shape)
df1 = df[df['ConvertedComp'].le(Q3 + 1.5*IQR)]
print('total number in new dataset:',df1.shape[0])
df[df['ConvertedComp'].gt(Q3 + 1.5*IQR)].shape
print('total number of outliers removed:',df2.shape[0])
df3 = df[df['ConvertedComp'].isnull()]
print('total number of nulls removed:',df3.shape[0])
print('total of outliers + inliers + nulls:', (9703 + 879 + 816))
# Out:
# (11398, 85)
# (11398,)
# total number in new dataset: 9703
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\morteza\Downloads\M3ExploratoryDataAnalysis-lab.ipynb Cell 45 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/morteza/Downloads/M3ExploratoryDataAnalysis-lab.ipynb#X60sZmlsZQ%3D%3D?line=4'>5</a> print('total number in new dataset:',df1.shape[0])
#       <a href='vscode-notebook-cell:/c%3A/Users/morteza/Downloads/M3ExploratoryDataAnalysis-lab.ipynb#X60sZmlsZQ%3D%3D?line=5'>6</a> df[df['ConvertedComp'].gt(Q3 + 1.5*IQR)].shape
# ----> <a href='vscode-notebook-cell:/c%3A/Users/morteza/Downloads/M3ExploratoryDataAnalysis-lab.ipynb#X60sZmlsZQ%3D%3D?line=6'>7</a> print('total number of outliers removed:',df2.shape[0])
#       <a href='vscode-notebook-cell:/c%3A/Users/morteza/Downloads/M3ExploratoryDataAnalysis-lab.ipynb#X60sZmlsZQ%3D%3D?line=7'>8</a> df3 = df[df['ConvertedComp'].isnull()]
#       <a href='vscode-notebook-cell:/c%3A/Users/morteza/Downloads/M3ExploratoryDataAnalysis-lab.ipynb#X60sZmlsZQ%3D%3D?line=8'>9</a> print('total number of nulls removed:',df3.shape[0])
#
# NameError: name 'df2' is not defined

# %%
df["Age"].median()
# Out:
# 29.0

# %%
# Out:
#   Input In [34]
#     df[["ConvertedComp"] == df["Gender]=="Woman"].median()
#                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df.corr()["Age"]
# Out:
# Respondent       0.004041
# CompTotal        0.006970
# ConvertedComp    0.105386
# WorkWeekHrs      0.036518
# CodeRevHrs      -0.020469
# Age              1.000000
# Name: Age, dtype: float64

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
